# %%
import pandas as pd
import lightgbm as lgb
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cross_validation import train_test_split  
from skopt import BayesSearchCV
import gc
import os
import psutil
import time
# Out:
# /Users/lin/miniconda2/lib/python2.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
train_cols = ['ip', 'app', 'os', 'device', 'channel', 
              'nextClick', 'ip_dev', 'X8', 
              'hour','is_attributed', 'os_count', 
              'app_count','time_delta_ip_dev', 
              'ip_app_day_hour_count', 'time_delta_ip_app', 'ip_count', 'X0']

# %%
dtypes = {
        'ip'                          : 'uint32',
        'app'                         : 'uint16',
        'os'                          : 'uint16',
        'channel'                     : 'uint16',
        'device'                      : 'uint16',
        'is_attributed'               : 'float16',
        'hour'                        : 'uint8',
        'ip_count'                    : 'uint16',
        'app_count'                   : 'uint16',
        'os_count'                    : 'uint16',
        'ip_app_day_hour_count'       : 'uint16',
        'ip_dev'                      : 'uint32',
        'X0'                          : 'uint16',
        'X8'                          : 'uint16',
        'nextClick'                   : 'float32',
        'time_delta_ip_app'           : 'float32',
        'time_delta_ip_dev'           : 'float32'
        }

# %%
skip = range(1,38941878)
print("Loading Data")
train = pd.read_csv('train_after.csv',dtype=dtypes,usecols=train_cols,header=0)
len_train = len(train) - 18790469
print("len_train: ",len_train)
# Out:
# Loading Data
# ('len_train: ', 184903890)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 203694359 entries, 0 to 203694358
# Data columns (total 17 columns):
# app                      uint16
# channel                  uint16
# device                   uint16
# ip                       uint32
# is_attributed            float16
# os                       uint16
# hour                     uint8
# ip_count                 uint16
# app_count                uint16
# os_count                 uint16
# ip_app_day_hour_count    uint16
# ip_dev                   uint32
# X0                       uint16
# X8                       uint16
# nextClick                float32
# time_delta_ip_app        float32
# time_delta_ip_dev        float32
# dtypes: float16(1), float32(3), uint16(10), uint32(2), uint8(1)
# memory usage: 8.2 GB

# %%
#Change Here When Change feature
predictors = ['ip', 'app', 'os', 'device', 'channel', 
              'nextClick',  'ip_dev', 'X8', 
              'hour', 'os_count', 
              'app_count','time_delta_ip_dev',  
              'ip_app_day_hour_count', 'time_delta_ip_app', 'ip_count', 'X0']

categorical = ['ip', 'app', 'device', 'os', 'channel', 'hour']

gc.collect()
# Out:
# 17

# %%
#68941878(2017-11-08 00:00:00) [68941878:131886952]
#131886953(2017-11-09 00:00:00)[131886953:]
#62945076   2017-11-08 23:59:59
#62945077   2017-11-09 00:00:00

# %%
# #use Day 8 as train, day 9 as valid
# splitTar = 62945076
# test = train[len_train:]
# train_ = train[:len_train]
# train_X = train_[:splitTar]
# val_X = train_[splitTar:]
# train_y = train_[:splitTar].is_attributed
# val_y = train_[splitTar:].is_attributed
# train_y = train_y.astype('uint8')
# val_y = val_y.astype('uint8')
# print('The size of the test set is ', len(test))
# print('The size of the validation set is ', len(val_X))
# print('The size of the train set is ', len(train_X))

# del train
# del train_
# gc.collect()

# %%
#random split for both 
test = train[len_train:]
train_ = train[:len_train]
target = 'is_attributed'
target = train_[target]
train_X,val_X, train_y, val_y = train_test_split(train_,target,test_size = 0.25,random_state = 0) 
train_y = train_y.astype('uint8')
val_y = val_y.astype('uint8')
print('The size of the test set is ', len(test))
print('The size of the validation set is ', len(val_X))
print('The size of the train set is ', len(train_X))

del train
del train_
gc.collect()
# Out:
# ('The size of the test set is ', 18790469)
# ('The size of the validation set is ', 46225973)
# ('The size of the train set is ', 138677917)
# 13

# %%
print("Preparing the datasets for training...")

params = {
    'boosting_type': 'gbdt',
    'objective': 'binary',
    'metric': 'auc',
    'learning_rate': 0.05,
    'num_leaves': 31,  
    'max_depth': -1,  
    'min_child_samples': 100,  
    'max_bin': 100,  
    'subsample': 0.7,  
    'subsample_freq': 1,  
    'colsample_bytree': 0.7,  
    'min_child_weight': 0,  
    'subsample_for_bin': 200000,  
    'min_split_gain': 0,  
    'reg_alpha': 0,  
    'reg_lambda': 0,  
   # 'nthread': 8,
    'verbose': 0,
    'scale_pos_weight':100 
    }

dtrain = lgb.Dataset(train_X[predictors].values, label=train_y.values,
                      feature_name=predictors,
                      categorical_feature=categorical
                      )
dvalid = lgb.Dataset(val_X[predictors].values, label=val_y.values,
                      feature_name=predictors,
                      categorical_feature=categorical
                      )
                      
evals_results = {}

del train_X
del val_X
gc.collect()
# Out:
# Preparing the datasets for training...
# 37

# %%
print("Training the model...")

lgb_model = lgb.train(params, 
                 dtrain, 
                 valid_sets=[dtrain, dvalid], 
                 valid_names=['train','valid'], 
                 evals_result=evals_results, 
                 num_boost_round=1500,
                 early_stopping_rounds=50,
                 verbose_eval=True, 
                 feval=None)
# Out:
# Training the model...
# /Users/lin/miniconda2/lib/python2.7/site-packages/lightgbm/basic.py:1036: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# /Users/lin/miniconda2/lib/python2.7/site-packages/lightgbm/basic.py:681: UserWarning: categorical_feature in param dict is overridden.
#   warnings.warn('categorical_feature in param dict is overridden.')
# [1]	train's auc: 0.944214	valid's auc: 0.943216
# Training until validation scores don't improve for 50 rounds.
# [2]	train's auc: 0.960265	valid's auc: 0.959424
# [3]	train's auc: 0.969704	valid's auc: 0.968854
# [4]	train's auc: 0.970087	valid's auc: 0.969137
# [5]	train's auc: 0.971316	valid's auc: 0.97038
# [6]	train's auc: 0.973147	valid's auc: 0.972281
# [7]	train's auc: 0.973095	valid's auc: 0.972245
# [8]	train's auc: 0.973794	valid's auc: 0.97295
# [9]	train's auc: 0.973943	valid's auc: 0.973137
# [10]	train's auc: 0.974665	valid's auc: 0.973866
# [11]	train's auc: 0.97485	valid's auc: 0.974044
# [12]	train's auc: 0.974682	valid's auc: 0.973873
# [13]	train's auc: 0.974645	valid's auc: 0.973805
# [14]	train's auc: 0.974937	valid's auc: 0.974113
# [15]	train's auc: 0.975271	valid's auc: 0.974444
# [16]	train's auc: 0.975315	valid's auc: 0.974486
# [17]	train's auc: 0.97547	valid's auc: 0.974624
# [18]	train's auc: 0.975586	valid's auc: 0.97473
# [19]	train's auc: 0.97575	valid's auc: 0.974909
# [20]	train's auc: 0.975785	valid's auc: 0.974941
# [21]	train's auc: 0.975942	valid's auc: 0.97511
# [22]	train's auc: 0.976116	valid's auc: 0.975306
# [23]	train's auc: 0.976246	valid's auc: 0.97544
# [24]	train's auc: 0.976267	valid's auc: 0.975458
# [25]	train's auc: 0.976622	valid's auc: 0.975868
# [26]	train's auc: 0.97662	valid's auc: 0.975867
# [27]	train's auc: 0.976669	valid's auc: 0.975911
# [28]	train's auc: 0.976602	valid's auc: 0.975842
# [29]	train's auc: 0.976651	valid's auc: 0.975871
# [30]	train's auc: 0.976668	valid's auc: 0.975882
# [31]	train's auc: 0.976749	valid's auc: 0.975932
# [32]	train's auc: 0.976704	valid's auc: 0.975879
# [33]	train's auc: 0.976904	valid's auc: 0.976037
# [34]	train's auc: 0.977058	valid's auc: 0.976139
# [35]	train's auc: 0.977146	valid's auc: 0.976229
# [36]	train's auc: 0.977248	valid's auc: 0.976323
# [37]	train's auc: 0.977379	valid's auc: 0.976437
# [38]	train's auc: 0.977414	valid's auc: 0.976431
# [39]	train's auc: 0.977452	valid's auc: 0.976422
# [40]	train's auc: 0.977456	valid's auc: 0.976415
# [41]	train's auc: 0.977461	valid's auc: 0.976426
# [42]	train's auc: 0.977589	valid's auc: 0.97655
# [43]	train's auc: 0.977605	valid's auc: 0.976526
# [44]	train's auc: 0.97782	valid's auc: 0.976688
# [45]	train's auc: 0.978043	valid's auc: 0.976902
# [46]	train's auc: 0.978227	valid's auc: 0.977102
# [47]	train's auc: 0.978303	valid's auc: 0.977077
# [48]	train's auc: 0.978536	valid's auc: 0.977279
# [49]	train's auc: 0.978528	valid's auc: 0.977232
# [50]	train's auc: 0.97852	valid's auc: 0.977236
# [51]	train's auc: 0.97879	valid's auc: 0.977532
# [52]	train's auc: 0.97902	valid's auc: 0.977642
# [53]	train's auc: 0.979269	valid's auc: 0.977921
# [54]	train's auc: 0.979253	valid's auc: 0.97791
# [55]	train's auc: 0.97931	valid's auc: 0.977851
# [56]	train's auc: 0.979364	valid's auc: 0.977786
# [57]	train's auc: 0.979627	valid's auc: 0.977934
# [58]	train's auc: 0.979844	valid's auc: 0.978184
# [59]	train's auc: 0.97984	valid's auc: 0.978122
# [60]	train's auc: 0.980006	valid's auc: 0.978303
# [61]	train's auc: 0.980115	valid's auc: 0.9783
# [62]	train's auc: 0.98014	valid's auc: 0.978258
# [63]	train's auc: 0.980391	valid's auc: 0.978359
# [64]	train's auc: 0.980596	valid's auc: 0.978591
# [65]	train's auc: 0.980868	valid's auc: 0.978738
# [66]	train's auc: 0.981033	valid's auc: 0.978923
# [67]	train's auc: 0.981296	valid's auc: 0.979222
# [68]	train's auc: 0.981461	valid's auc: 0.979402
# [69]	train's auc: 0.981637	valid's auc: 0.979464
# [70]	train's auc: 0.981732	valid's auc: 0.979437
# [71]	train's auc: 0.981861	valid's auc: 0.97961
# [72]	train's auc: 0.982153	valid's auc: 0.979758
# [73]	train's auc: 0.98236	valid's auc: 0.979832
# [74]	train's auc: 0.982448	valid's auc: 0.979797
# [75]	train's auc: 0.98263	valid's auc: 0.979866
# [76]	train's auc: 0.982786	valid's auc: 0.979869
# [77]	train's auc: 0.982984	valid's auc: 0.979994
# [78]	train's auc: 0.983025	valid's auc: 0.979961
# [79]	train's auc: 0.983182	valid's auc: 0.980156
# [80]	train's auc: 0.983307	valid's auc: 0.980177
# [81]	train's auc: 0.983448	valid's auc: 0.980352
# [82]	train's auc: 0.983475	valid's auc: 0.980331
# [83]	train's auc: 0.983516	valid's auc: 0.980372
# [84]	train's auc: 0.983538	valid's auc: 0.980395
# [85]	train's auc: 0.983634	valid's auc: 0.980533
# [86]	train's auc: 0.983834	valid's auc: 0.980608
# [87]	train's auc: 0.983949	valid's auc: 0.980667
# [88]	train's auc: 0.984021	valid's auc: 0.980769
# [89]	train's auc: 0.984175	valid's auc: 0.9808
# [90]	train's auc: 0.984295	valid's auc: 0.980826
# [91]	train's auc: 0.984399	valid's auc: 0.98087
# [92]	train's auc: 0.984541	valid's auc: 0.980951
# [93]	train's auc: 0.98465	valid's auc: 0.980936
# [94]	train's auc: 0.984757	valid's auc: 0.981088
# [95]	train's auc: 0.984912	valid's auc: 0.981163
# [96]	train's auc: 0.985021	valid's auc: 0.981163
# [97]	train's auc: 0.985123	valid's auc: 0.981182
# [98]	train's auc: 0.985204	valid's auc: 0.981303
# [99]	train's auc: 0.985361	valid's auc: 0.981402
# [100]	train's auc: 0.985435	valid's auc: 0.981407
# [101]	train's auc: 0.98556	valid's auc: 0.981483
# [102]	train's auc: 0.985667	valid's auc: 0.981577
# [103]	train's auc: 0.985761	valid's auc: 0.981601
# [104]	train's auc: 0.985839	valid's auc: 0.981711
# [105]	train's auc: 0.985945	valid's auc: 0.981784
# [106]	train's auc: 0.986	valid's auc: 0.981867
# [107]	train's auc: 0.986063	valid's auc: 0.981962
# [108]	train's auc: 0.986187	valid's auc: 0.982002
# [109]	train's auc: 0.986271	valid's auc: 0.982061
# [110]	train's auc: 0.986361	valid's auc: 0.982088
# [111]	train's auc: 0.986443	valid's auc: 0.982095
# [112]	train's auc: 0.986517	valid's auc: 0.982136
# [113]	train's auc: 0.986558	valid's auc: 0.982209
# [114]	train's auc: 0.986623	valid's auc: 0.982222
# [115]	train's auc: 0.986658	valid's auc: 0.982259
# [116]	train's auc: 0.986753	valid's auc: 0.982281
# [117]	train's auc: 0.986778	valid's auc: 0.982313
# [118]	train's auc: 0.986854	valid's auc: 0.982358
# [119]	train's auc: 0.986898	valid's auc: 0.98241
# [120]	train's auc: 0.986986	valid's auc: 0.982443
# [121]	train's auc: 0.987066	valid's auc: 0.982457
# [122]	train's auc: 0.987112	valid's auc: 0.98253
# [123]	train's auc: 0.987143	valid's auc: 0.982562
# [124]	train's auc: 0.9872	valid's auc: 0.982585
# [125]	train's auc: 0.987287	valid's auc: 0.982618
# [126]	train's auc: 0.987349	valid's auc: 0.982638
# [127]	train's auc: 0.987394	valid's auc: 0.982661
# [128]	train's auc: 0.987449	valid's auc: 0.98266
# [129]	train's auc: 0.98751	valid's auc: 0.982687
# [130]	train's auc: 0.987534	valid's auc: 0.982709
# [131]	train's auc: 0.987561	valid's auc: 0.982741
# [132]	train's auc: 0.987588	valid's auc: 0.982772
# [133]	train's auc: 0.987642	valid's auc: 0.982791
# [134]	train's auc: 0.987671	valid's auc: 0.982814
# [135]	train's auc: 0.987739	valid's auc: 0.982825
# [136]	train's auc: 0.987764	valid's auc: 0.982873
# [137]	train's auc: 0.987814	valid's auc: 0.982887
# [138]	train's auc: 0.987868	valid's auc: 0.982898
# [139]	train's auc: 0.987925	valid's auc: 0.982929
# [140]	train's auc: 0.987974	valid's auc: 0.982952
# [141]	train's auc: 0.988043	valid's auc: 0.982951
# [142]	train's auc: 0.988063	valid's auc: 0.982985
# [143]	train's auc: 0.988092	valid's auc: 0.983032
# [144]	train's auc: 0.988113	valid's auc: 0.983071
# [145]	train's auc: 0.988147	valid's auc: 0.983074
# [146]	train's auc: 0.988197	valid's auc: 0.983083
# [147]	train's auc: 0.988237	valid's auc: 0.983097
# [148]	train's auc: 0.988268	valid's auc: 0.983124
# [149]	train's auc: 0.988314	valid's auc: 0.983144
# [150]	train's auc: 0.988337	valid's auc: 0.983151
# [151]	train's auc: 0.988371	valid's auc: 0.983177
# [152]	train's auc: 0.988412	valid's auc: 0.983186
# [153]	train's auc: 0.98844	valid's auc: 0.983196
# [154]	train's auc: 0.988462	valid's auc: 0.983222
# [155]	train's auc: 0.98849	valid's auc: 0.98324
# [156]	train's auc: 0.988527	valid's auc: 0.983247
# [157]	train's auc: 0.988559	valid's auc: 0.983253
# [158]	train's auc: 0.988585	valid's auc: 0.983278
# [159]	train's auc: 0.988599	valid's auc: 0.983295
# [160]	train's auc: 0.988617	valid's auc: 0.983315
# [161]	train's auc: 0.988647	valid's auc: 0.983316
# [162]	train's auc: 0.988683	valid's auc: 0.983326
# [163]	train's auc: 0.988711	valid's auc: 0.983361
# [164]	train's auc: 0.988743	valid's auc: 0.983369
# [165]	train's auc: 0.988789	valid's auc: 0.983378
# [166]	train's auc: 0.988824	valid's auc: 0.983396
# [167]	train's auc: 0.988848	valid's auc: 0.983429
# [168]	train's auc: 0.988898	valid's auc: 0.983441
# [169]	train's auc: 0.988922	valid's auc: 0.983449
# [170]	train's auc: 0.988946	valid's auc: 0.983457
# [171]	train's auc: 0.98897	valid's auc: 0.983458
# [172]	train's auc: 0.988995	valid's auc: 0.983469
# [173]	train's auc: 0.989034	valid's auc: 0.983472
# [174]	train's auc: 0.989047	valid's auc: 0.983486
# [175]	train's auc: 0.989065	valid's auc: 0.983492
# [176]	train's auc: 0.989091	valid's auc: 0.983491
# [177]	train's auc: 0.989113	valid's auc: 0.983527
# [178]	train's auc: 0.989141	valid's auc: 0.983539
# [179]	train's auc: 0.989168	valid's auc: 0.983538
# [180]	train's auc: 0.989198	valid's auc: 0.983544
# [181]	train's auc: 0.989233	valid's auc: 0.983558
# [182]	train's auc: 0.989253	valid's auc: 0.983578
# [183]	train's auc: 0.989269	valid's auc: 0.9836
# [184]	train's auc: 0.989299	valid's auc: 0.983603
# [185]	train's auc: 0.989314	valid's auc: 0.983621
# [186]	train's auc: 0.989336	valid's auc: 0.983626
# [187]	train's auc: 0.989349	valid's auc: 0.983642
# [188]	train's auc: 0.98937	valid's auc: 0.98367
# [189]	train's auc: 0.989385	valid's auc: 0.98369
# [190]	train's auc: 0.989412	valid's auc: 0.983704
# [191]	train's auc: 0.989428	valid's auc: 0.983717
# [192]	train's auc: 0.989447	valid's auc: 0.983722
# [193]	train's auc: 0.989465	valid's auc: 0.983725
# [194]	train's auc: 0.989479	valid's auc: 0.983741
# [195]	train's auc: 0.989486	valid's auc: 0.983754
# [196]	train's auc: 0.989507	valid's auc: 0.983759
# [197]	train's auc: 0.989528	valid's auc: 0.983764
# [198]	train's auc: 0.98955	valid's auc: 0.983768
# [199]	train's auc: 0.989563	valid's auc: 0.983787
# [200]	train's auc: 0.989574	valid's auc: 0.983798
# [201]	train's auc: 0.989593	valid's auc: 0.983798
# [202]	train's auc: 0.989613	valid's auc: 0.983811
# [203]	train's auc: 0.989629	valid's auc: 0.983837
# [204]	train's auc: 0.989644	valid's auc: 0.983859
# [205]	train's auc: 0.989661	valid's auc: 0.983858
# [206]	train's auc: 0.989673	valid's auc: 0.983872
# [207]	train's auc: 0.989693	valid's auc: 0.983882
# [208]	train's auc: 0.989714	valid's auc: 0.983885
# [209]	train's auc: 0.989727	valid's auc: 0.983906
# [210]	train's auc: 0.989747	valid's auc: 0.98391
# [211]	train's auc: 0.989759	valid's auc: 0.983908
# [212]	train's auc: 0.989784	valid's auc: 0.983911
# [213]	train's auc: 0.989796	valid's auc: 0.983917
# [214]	train's auc: 0.989807	valid's auc: 0.983919
# [215]	train's auc: 0.989822	valid's auc: 0.983923
# [216]	train's auc: 0.989831	valid's auc: 0.983937
# [217]	train's auc: 0.98984	valid's auc: 0.98394
# [218]	train's auc: 0.989855	valid's auc: 0.983958
# [219]	train's auc: 0.989868	valid's auc: 0.983957
# [220]	train's auc: 0.989878	valid's auc: 0.983957
# [221]	train's auc: 0.989885	valid's auc: 0.983966
# [222]	train's auc: 0.989897	valid's auc: 0.983967
# [223]	train's auc: 0.989915	valid's auc: 0.983967
# [224]	train's auc: 0.989929	valid's auc: 0.983966
# [225]	train's auc: 0.989937	valid's auc: 0.983968
# [226]	train's auc: 0.98996	valid's auc: 0.983965
# [227]	train's auc: 0.98997	valid's auc: 0.983977
# [228]	train's auc: 0.989982	valid's auc: 0.983978
# [229]	train's auc: 0.990001	valid's auc: 0.983982
# [230]	train's auc: 0.99002	valid's auc: 0.98398
# [231]	train's auc: 0.990032	valid's auc: 0.983982
# [232]	train's auc: 0.99005	valid's auc: 0.983984
# [233]	train's auc: 0.990059	valid's auc: 0.983996
# [234]	train's auc: 0.990077	valid's auc: 0.983998
# [235]	train's auc: 0.990087	valid's auc: 0.983999
# [236]	train's auc: 0.990097	valid's auc: 0.983999
# [237]	train's auc: 0.990105	valid's auc: 0.984008
# [238]	train's auc: 0.990115	valid's auc: 0.984018
# [239]	train's auc: 0.990127	valid's auc: 0.984017
# [240]	train's auc: 0.990143	valid's auc: 0.98403
# [241]	train's auc: 0.99016	valid's auc: 0.984031
# [242]	train's auc: 0.990167	valid's auc: 0.984032
# [243]	train's auc: 0.990179	valid's auc: 0.984035
# [244]	train's auc: 0.990187	valid's auc: 0.984035
# [245]	train's auc: 0.990195	valid's auc: 0.984035
# [246]	train's auc: 0.990208	valid's auc: 0.984049
# [247]	train's auc: 0.990217	valid's auc: 0.984048
# [248]	train's auc: 0.990226	valid's auc: 0.984058
# [249]	train's auc: 0.990234	valid's auc: 0.984064
# [250]	train's auc: 0.990249	valid's auc: 0.984077
# [251]	train's auc: 0.990259	valid's auc: 0.984078
# [252]	train's auc: 0.99027	valid's auc: 0.98408
# [253]	train's auc: 0.990279	valid's auc: 0.984088
# [254]	train's auc: 0.990285	valid's auc: 0.984096
# [255]	train's auc: 0.99029	valid's auc: 0.984102
# [256]	train's auc: 0.99031	valid's auc: 0.984097
# [257]	train's auc: 0.990318	valid's auc: 0.984098
# [258]	train's auc: 0.990328	valid's auc: 0.984099
# [259]	train's auc: 0.990334	valid's auc: 0.984098
# [260]	train's auc: 0.990337	valid's auc: 0.984095
# [261]	train's auc: 0.990345	valid's auc: 0.984102
# [262]	train's auc: 0.990356	valid's auc: 0.984102
# [263]	train's auc: 0.99036	valid's auc: 0.9841
# [264]	train's auc: 0.990364	valid's auc: 0.984098
# [265]	train's auc: 0.990368	valid's auc: 0.984095
# [266]	train's auc: 0.990372	valid's auc: 0.984091
# [267]	train's auc: 0.990383	valid's auc: 0.98409
# [268]	train's auc: 0.99039	valid's auc: 0.984087
# [269]	train's auc: 0.990398	valid's auc: 0.984098
# [270]	train's auc: 0.990405	valid's auc: 0.984113
# [271]	train's auc: 0.990411	valid's auc: 0.984111
# [272]	train's auc: 0.990417	valid's auc: 0.984109
# [273]	train's auc: 0.990421	valid's auc: 0.984107
# [274]	train's auc: 0.990428	valid's auc: 0.984117
# [275]	train's auc: 0.990437	valid's auc: 0.984129
# [276]	train's auc: 0.990444	valid's auc: 0.984128
# [277]	train's auc: 0.990448	valid's auc: 0.984124
# [278]	train's auc: 0.990454	valid's auc: 0.984124
# [279]	train's auc: 0.99046	valid's auc: 0.984122
# [280]	train's auc: 0.990466	valid's auc: 0.984121
# [281]	train's auc: 0.99047	valid's auc: 0.984119
# [282]	train's auc: 0.990479	valid's auc: 0.984128
# [283]	train's auc: 0.990483	valid's auc: 0.984125
# [284]	train's auc: 0.990488	valid's auc: 0.98412
# [285]	train's auc: 0.990494	valid's auc: 0.98412

# %%
#train's auc: 0.988606	valid's auc: 0.984418 0.1, 4, 12

# %%
# f, ax = plt.subplots(figsize=[15,10])
# lgb.plot_importance(lgb_model, ax=ax,)
# plt.title("Light GBM Feature Importance")
# plt.savefig('feature_import1.png')

# # Feature names:
# print('Feature names:', lgb_model.feature_name())
# # Feature importances:
# print('Feature importances:', list(lgb_model.feature_importance()))

# feature_imp = pd.DataFrame(lgb_model.feature_name(),list(lgb_model.feature_importance()))

# %%
print("Preparing data for submission...")

submit = pd.read_csv('test.csv', dtype='int', usecols=['click_id'])

print("Predicting the submission data...")

#submit['is_attributed'] = 0
submit['is_attributed'] = lgb_model.predict(test[predictors], num_iteration=lgb_model.best_iteration)
#submit['is_attributed'] = lgb_model_re.predict(test[predictors], num_iteration= -1)


print("Writing the submission data into a csv file...")
print(submit.shape)
submit.to_csv('submission_lgb_x4.csv', index=False)

print("All done...")
